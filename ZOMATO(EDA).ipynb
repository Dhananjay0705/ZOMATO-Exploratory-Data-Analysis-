# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhananjay0705/ZOMATO-Exploratory-Data-Analysis-/blob/main/ZOMATO(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ZOMATO Dataset Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
